# %%
# !pwd
# Out:
# /home/yongsu/aspect

# %% [markdown]
# ### Run test

# %%
# !python3 main.py --test electronics --save_dir ./data/electronics --model ./data/electronics/model/2_512_1024/117_aspect_planning.tar
# Out:
# layers, hidden, batch_size:  2 512 1024
# Start loading training data ...
# # train instances:  94429
# testing the model "./data/electronics/model/2_512_1024/117_aspect_planning.tar"
# Building encoder and decoder ...
# cuda is available? 0(device id: 0) (among 8 available ones)
# encoder:  cpu
# =============================================================
# Context:  A2HOXL7H84SCY6	B004UTQRHW	4
# Aspects >  canon quality quality
# /home/yongsu/aspect/evaluate.py:298: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   attr_input = Variable(torch.LongTensor([sentence]), volatile=True)
# Evaluate with conditional_beam_decoder
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]])]
# Predicted aspects:  product <eos> <sos> product product product product <eos> <sos> product product product <eos> <eos> product product <sos> <eos> quality product product product product <sos>
# =============================================================
# Context:  AU4HCPNI9LJ0U	B005VAONLQ	4
# Aspects >  cables cables cables
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price product product product quality <eos> <sos> price product product product <eos> <eos> product product price <sos> <eos> product price <sos>
# =============================================================
# Context:  A2P3V1BG6FMUS5	B000AJIF4E	5
# Aspects >  cord sound pair
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price camera quality <eos> <sos> price camera quality quality <eos> <eos> quality quality quality camera price <sos> <eos> camera price <sos>
# =============================================================
# Context:  AZBHHMMA9G4L2	B00C2JCXHU	4
# Aspects >  pen quality
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price product product product <eos> <sos> price product product <eos> <eos> product price <sos> <eos> product product product product price <sos>
# =============================================================
# Context:  A3OSUAAXSUNPLM	B000NK8EWI	5
# Aspects >  resolution buy camera
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price product product quality <eos> <sos> price product product <eos> <eos> product price <sos> <eos> quality quality product product price <sos>
# =============================================================
# Context:  AV111BU36Q2FW	B002NEG0VO	5
# Aspects >  laptop port speakers speaker size
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price quality <eos> <sos> price price quality quality <eos> <eos> quality quality quality price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A38RMU1Y5TDP9	B00009XW5J	3
# Aspects >  lighting cost
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# Predicted aspects:  sound sound sound <eos> <sos> sound sound sound sound sound <eos> <sos> sound sound sound sound sound sound sound <eos> <eos> sound sound sound sound sound sound <sos> <eos> sound sound sound sound <sos>
# =============================================================
# Context:  A3A18ELO01FE5R	B00FRBPK5W	5
# Aspects >  fits color
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# Predicted aspects:  sound <eos> <sos> sound sound sound <eos> <sos> sound sound sound sound sound <eos> <eos> sound sound sound sound <sos> <eos> sound sound <sos>
# =============================================================
# Context:  A2P8536TV2X0HV	B00F96JG78	2
# Aspects >  tablet screen
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound <eos> <sos> price price sound sound sound <eos> <eos> sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A2MPQHYMT258ZV	B000GVTX6U	4
# Aspects >  router setup setup router
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound <eos> <eos> sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A20R8N25W187LY	B001RI91E0	4
# Aspects >  tripod tripod
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# Predicted aspects:  camera <eos> <sos> camera camera camera camera camera <eos> <sos> camera camera camera camera <eos> <eos> camera camera camera <sos> <eos> camera camera <sos>
# =============================================================
# Context:  A1VYUTJ8PLNZPJ	B005X0JTP4	5
# Aspects >  fits fit product
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound sound <eos> <eos> sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A36N69V7OXXB2T	B004HYGU18	4
# Aspects >  monitor scrolling surface mouse size programs
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# Predicted aspects:  camera camera <eos> <sos> camera camera camera camera <eos> <sos> camera camera camera camera camera <eos> <eos> camera camera camera camera camera camera <sos> <eos> camera camera camera <sos>
# =============================================================
# Context:  A3Q4TYJVAM4IRM	B00009R6WU	5
# Aspects >  photos shooting
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A2FU1GTCRPMYB0	B007M50PTM	5
# Aspects >  tablet def
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]])]
# Predicted aspects:  product <eos> <sos> product product <eos> <sos> product product product <eos> <eos> quality product product product <sos> <eos> quality quality product product product <sos>
# =============================================================
# Context:  AK3GKIV8DEY8B	B00004ZCDD	1
# Aspects >  lens filter photos
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price camera camera camera camera <eos> <sos> price camera camera camera <eos> <eos> camera camera price <sos> <eos> camera price <sos>
# =============================================================
# Context:  AF03A958JD9GO	B0018P0S1M	5
# Aspects >  cam quality image quality device device
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound <eos> <sos> price price sound sound <eos> <eos> sound sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A38GWJFK5UEKL2	B0002MRO2S	5
# Aspects >  keyboard keyboard charge
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price price quality <eos> <sos> price price <eos> <eos> price price price <sos> <eos> quality quality price price price <sos>
# =============================================================
# Context:  A522R52NA6GIB	B006I5MKZY	3
# Aspects >  features product
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound sound sound <eos> <sos> price sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A6FIAB28IS79	B000NDO744	3
# Aspects >  ge unit machine
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price quality quality quality <eos> <sos> price quality quality <eos> <eos> quality price <sos> <eos> quality quality quality quality price <sos>
# =============================================================
# Context:  A1PT2ZJIG0LYBN	B007R5YGO2	5
# Aspects >  fit cover
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price quality quality quality quality <eos> <sos> price quality quality <eos> <eos> quality quality quality price <sos> <eos> quality price <sos>
# =============================================================
# Context:  A164BNFAXZTX6I	B0096YOQRY	4
# Aspects >  video product tv tv compact video
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# Predicted aspects:  camera camera <eos> <sos> camera camera camera camera camera camera <eos> <sos> camera camera camera camera camera <eos> <eos> camera camera camera camera <sos> <eos> camera camera camera <sos>
# =============================================================
# Context:  A3N4VTNFPMTHEF	B00DCM91WQ	4
# Aspects >  7mm performance performance power consumption drive drive drive notebook
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[0]])]
# Predicted aspects:  sound <eos> <sos> sound sound sound sound sound <eos> <sos> sound sound sound <eos> <eos> sound sound sound sound <sos> <eos> sound sound <sos>
# =============================================================
# Context:  A1MIGKTN61WBU1	B00BW6LTG0	5
# Aspects >  pictures camera
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound <eos> <sos> price price sound <eos> <eos> price price <sos> <eos> sound sound sound price price <sos>
# =============================================================
# Context:  A2XYH8IHILWW7X	B0031RG29M	4
# Aspects >  compact file size size computer
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1674]]), tensor([[1674]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1674]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price product product <eos> <sos> price product product quality <eos> <eos> quality quality product product price <sos> <eos> product price <sos>
# =============================================================
# Context:  A3F0TAVYANCHW5	B004SPVZKW	4
# Aspects >  product products
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound <eos> <eos> sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  AC871EE3C5P1R	B0039YXNVC	4
# Aspects >  connector drive
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A1O8U5AAWMBCLJ	B006DDT6JO	3
# Aspects >  flash computer files
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price camera <eos> <sos> price price price <eos> <eos> price price <sos> <eos> camera camera price price <sos>
# =============================================================
# Context:  A18KL9WSP4NMPY	B004QXAK70	5
# Aspects >  video camera plastic
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A1QD7GSIVI81I8	B000WL6YY8	4
# Aspects >  price construction
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound <eos> <eos> sound sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A1R27GA0XBM0HR	B0064H6QGA	5
# Aspects >  phone speaker
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[0]])]
# Predicted aspects:  camera <eos> <sos> camera camera camera <eos> <sos> camera camera camera camera camera <eos> <eos> camera camera camera camera <sos> <eos> camera camera <sos>
# =============================================================
# Context:  A2K6CDQ9HZ359G	B009R99I8U	3
# Aspects >  video quality
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1674]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1674]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1674]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1674]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price product sound <eos> <sos> price price product <eos> <eos> price price <sos> <eos> sound sound product price price <sos>
# =============================================================
# Context:  A1J4R2VQT7HKLE	B004XZL980	5
# Aspects >  processor laptop
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price quality quality quality <eos> <sos> price price quality <eos> <eos> quality quality price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A3KPKQZZIHVQZM	B00DR0PDNE	1
# Aspects >  tv product device
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price quality quality quality <eos> <sos> price quality quality <eos> <eos> quality price <sos> <eos> quality quality quality quality price <sos>
# =============================================================
# Context:  A2KXZU9O2XVUS2	B005IHAI8O	5
# Aspects >  price lens lens lens plastic quality sharpness autofocus
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A1FM04G6G7HDCN	B003D8GAA0	2
# Aspects >  product product
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A2BA12Q8H0H9AF	B0054JJ0QW	5
# Aspects >  sound price headphones headphones headphones headphones quality
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound sound <eos> <eos> sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A2V0ITIWLEL8RY	B00065Q8IC	5
# Aspects >  grip plastic
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# ...
# Predicted aspects:  price price <eos> <sos> price price price <eos> <sos> price price price quality <eos> <eos> quality quality price price price <sos> <eos> quality quality quality price price price <sos>
# =============================================================
# Context:  A1P3DDFL423B3C	B0000U19F0	5
# Aspects >  headphones def sound noise sound headphones
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound <eos> <eos> sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A234L2MBIN7BIA	B00BUL4NLU	3
# Aspects >  volume cable buttons volume
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1674]]), tensor([[1674]]), tensor([[1]]), tensor([[1]]), tensor([[1674]]), tensor([[1674]]), tensor([[1674]]), tensor([[0]]), tensor([[1]]), tensor([[1674]]), tensor([[0]])]
# Predicted aspects:  <eos> <sos> product product product sound <eos> <sos> product product <eos> <eos> product product product <sos> <eos> product <sos>
# =============================================================
# Context:  A1OPKNO7IXWV27	B00001W0EQ	4
# Aspects >  sound quality headset
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price <eos> <sos> price price sound <eos> <eos> sound sound price price <sos> <eos> sound sound sound price price <sos>
# =============================================================
# Context:  A128XPDDWHEKGR	B009USAJCC	5
# Aspects >  charge ports size
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  AWPODHOB4GFWL	B004VTHKZE	3
# Aspects >  price charge batteries
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price quality quality quality <eos> <sos> price price quality <eos> <eos> quality quality price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A1SJ11UTVRJ1YP	B003ELYQGG	5
# Aspects >  sound noise
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1822]]), tensor([[1822]]), tensor([[1]]), tensor([[1]]), tensor([[1822]]), tensor([[1822]]), tensor([[1822]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price quality <eos> <sos> price price quality quality <eos> <eos> quality quality quality price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A3A463225ULBGE	B00E3W15P0	5
# Aspects >  def video card
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[2144]]), tensor([[2144]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[2144]]), tensor([[1]]), tensor([[1]]), tensor([[2144]]), tensor([[2144]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price camera camera camera <eos> <sos> price price camera <eos> <eos> camera camera price price <sos> <eos> price price <sos>
# =============================================================
# Context:  AHF2DDW7M5S60	B009F1JL5A	5
# Aspects >  screen product
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price sound sound <eos> <sos> price sound sound sound sound <eos> <eos> sound sound sound price <sos> <eos> sound price <sos>
# =============================================================
# Context:  A3EJZJQCMRRFT2	B0050SLTPC	4
# Aspects >  setup adapter adapter adapter setup
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price price <eos> <sos> price price sound sound sound sound <eos> <sos> price price sound sound <eos> <eos> sound sound sound price price <sos> <eos> sound price price <sos>
# =============================================================
# Context:  A128BT3YMA1K8B	B005Y586QQ	4
# Aspects >  quality quality cover cover cover
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound <eos> <eos> sound sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A1K0QSYSNAQTNY	B005F7RO20	5
# Aspects >  pairs touch edges kit inch cost pen size keyboard stores keyboard plastic fit size
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# Predicted aspects:  price <eos> <sos> price price sound sound sound <eos> <sos> price price sound sound <eos> <eos> sound price price <sos> <eos> price price <sos>
# =============================================================
# Context:  A3L3EEJYMUPM02	B000UPA4R4	5
# Aspects >  sound construction sound
# Evaluate with conditional_beam_decoder
# eos
# eos
# eos
# eos
# eos
# decoded[0]:  tensor([[0]])
# decoded:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[1]]), tensor([[1]]), tensor([[140]]), tensor([[140]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]]), tensor([[1]]), tensor([[1915]]), tensor([[1915]]), tensor([[0]])]
# best_hyp:  [tensor([[0]]), tensor([[1915]]), tensor([[1]]), tensor([[0]]), tensor([[1915]]), tensor([[1915]]), tensor([[140]]), tensor([[140]]), tensor([[140]]), ^C
# Traceback (most recent call last):
#   File "main.py", line 58, in <module>
#     run(args)
#   File "main.py", line 54, in run
#     args.model, beam_size, max_length, min_length, save_dir)
#   File "/home/yongsu/aspect/evaluate.py", line 430, in runTest
#     evaluateRandomly(encoder, aspect_decoder, vocab, user_rdict, item_rdict, test_pairs, len(test_pairs), beam_size, max_length, min_length, save_dir)
#   File "/home/yongsu/aspect/evaluate.py", line 358, in evaluateRandomly
#     best_hyp = evaluate(encoder, aspect_decoder, vocab, context_input, beam_size, max_length, min_length)
#   File "/home/yongsu/aspect/evaluate.py", line 301, in evaluate
#     encoder_out, encoder_hidden = encoder(attr_input)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/yongsu/aspect/model.py", line 25, in forward
#     embs.append(self.u_embedding(input[:, 0]))  # (batch) --> (batch, context_emb_size)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py", line 126, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/functional.py", line 1852, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# KeyboardInterrupt

# %% [markdown]
# ### Run training

# %%
# !python3 main.py --train electronics --save_dir ./data/electronics
# Out:
# corpus=electronics, learning_rate=0.0001, lr_decay_epoch=5, lr_decay_ratio=0.9, batch_size=1024, n_layers=2,     hidden_size=512, embed_size=512, context_emb_size=512, num_contexts=3, overall=5, save_dir=./data/electronics
# cuda is available? True(device id: 7) (among 8 available ones)
# load data...
# Start loading training data ...
# # train instances:  94429
# data loaded...
# Building encoder and decoder ...
# Building optimizers ...
# Initializing ...
# 2021-12-11 15:55:42.759233: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-11 15:55:42.759262: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /home/yongsu/aspect/masked_cross_entropy.py:40: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
#   loss = losses.masked_select(mask).mean()
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# /home/yongsu/aspect/train.py:77: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   ec = torch.nn.utils.clip_grad_norm(filter(lambda p: p.requires_grad, encoder.parameters()), clip)
# /home/yongsu/aspect/train.py:78: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   dc = torch.nn.utils.clip_grad_norm(filter(lambda p: p.requires_grad, aspect_decoder.parameters()), clip)
# epoch 0 batch 0 loss=8.134699821472168 perplexity=3410.792068549478 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   0 | average loss 0.08842 | average ppl    1.092
# ------------------------------
#
# ------------------------------
# valid | epoch   0 | valid loss 8.11462 | valid ppl 3342.978
# ------------------------------
#
# ------------------------------
# | test loss  8.11 | test ppl  3341.09
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 1 batch 0 loss=8.106942176818848 perplexity=3317.418425709854 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   1 | average loss 0.08812 | average ppl    1.092
# ------------------------------
#
# ------------------------------
# valid | epoch   1 | valid loss 8.09607 | valid ppl 3281.547
# ------------------------------
#
# ------------------------------
# | test loss  8.10 | test ppl  3280.16
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 2 batch 0 loss=8.08047103881836 perplexity=3230.754689156142 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   2 | average loss 0.08783 | average ppl    1.092
# ------------------------------
#
# ------------------------------
# valid | epoch   2 | valid loss 8.07618 | valid ppl 3216.923
# ------------------------------
#
# ------------------------------
# | test loss  8.08 | test ppl  3215.96
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 3 batch 0 loss=8.05169677734375 perplexity=3139.1168373294977 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   3 | average loss 0.08752 | average ppl    1.091
# ------------------------------
#
# ------------------------------
# valid | epoch   3 | valid loss 8.05422 | valid ppl 3147.054
# ------------------------------
#
# ------------------------------
# | test loss  8.05 | test ppl  3146.58
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 4 batch 0 loss=8.021771430969238 perplexity=3046.5693430307847 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   4 | average loss 0.08719 | average ppl    1.091
# ------------------------------
#
# ------------------------------
# valid | epoch   4 | valid loss 8.02948 | valid ppl 3070.159
# ------------------------------
#
# ------------------------------
# | test loss  8.03 | test ppl  3070.24
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 5 batch 0 loss=7.988956451416016 perplexity=2948.218744133912 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   5 | average loss 0.08684 | average ppl    1.091
# ------------------------------
#
# ------------------------------
# valid | epoch   5 | valid loss 8.00122 | valid ppl 2984.608
# ------------------------------
#
# ------------------------------
# | test loss  8.00 | test ppl  2985.24
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 6 batch 0 loss=7.952638626098633 perplexity=2843.066852360616 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   6 | average loss 0.08644 | average ppl    1.090
# ------------------------------
#
# ------------------------------
# valid | epoch   6 | valid loss 7.96858 | valid ppl 2888.741
# ------------------------------
#
# ------------------------------
# | test loss  7.97 | test ppl  2889.96
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 7 batch 0 loss=7.912618160247803 perplexity=2731.5327028392267 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   7 | average loss 0.08601 | average ppl    1.090
# ------------------------------
#
# ------------------------------
# valid | epoch   7 | valid loss 7.93060 | valid ppl 2781.083
# ------------------------------
#
# ------------------------------
# | test loss  7.93 | test ppl  2782.93
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 8 batch 0 loss=7.8665080070495605 perplexity=2608.441008362547 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   8 | average loss 0.08551 | average ppl    1.089
# ------------------------------
#
# ------------------------------
# valid | epoch   8 | valid loss 7.88621 | valid ppl 2660.343
# ------------------------------
#
# ------------------------------
# | test loss  7.89 | test ppl  2662.83
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 9 batch 0 loss=7.815335750579834 perplexity=2478.318910351859 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch   9 | average loss 0.08495 | average ppl    1.089
# ------------------------------
#
# ------------------------------
# valid | epoch   9 | valid loss 7.83413 | valid ppl 2525.339
# ------------------------------
# ------------------------------
# | test loss  7.84 | test ppl  2528.48
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 10 batch 0 loss=7.756863594055176 perplexity=2337.5615539462733 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  10 | average loss 0.08431 | average ppl    1.088
# ------------------------------
#
# ------------------------------
# valid | epoch  10 | valid loss 7.77294 | valid ppl 2375.453
# ------------------------------
#
# ------------------------------
# | test loss  7.77 | test ppl  2379.28
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 11 batch 0 loss=7.688532829284668 perplexity=2183.1691295312817 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  11 | average loss 0.08357 | average ppl    1.087
# ------------------------------
#
# ------------------------------
# valid | epoch  11 | valid loss 7.70111 | valid ppl 2210.801
# ------------------------------
#
# ------------------------------
# | test loss  7.70 | test ppl  2215.25
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 12 batch 0 loss=7.611093997955322 perplexity=2020.487298038968 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  12 | average loss 0.08273 | average ppl    1.086
# ------------------------------
#
# ------------------------------
# valid | epoch  12 | valid loss 7.61693 | valid ppl 2032.322
# ------------------------------
#
# ------------------------------
# | test loss  7.62 | test ppl  2037.38
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 13 batch 0 loss=7.520153522491455 perplexity=1844.8504983584853 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  13 | average loss 0.08174 | average ppl    1.085
# ------------------------------
#
# ------------------------------
# valid | epoch  13 | valid loss 7.51876 | valid ppl 1842.274
# ------------------------------
#
# ------------------------------
# | test loss  7.52 | test ppl  1847.81
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 14 batch 0 loss=7.418625831604004 perplexity=1666.7415497753207 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  14 | average loss 0.08064 | average ppl    1.084
# ------------------------------
#
# ------------------------------
# valid | epoch  14 | valid loss 7.40498 | valid ppl 1644.150
# ------------------------------
#
# ------------------------------
# | test loss  7.41 | test ppl  1650.05
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 15 batch 0 loss=7.300764083862305 perplexity=1481.4314330980849 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  15 | average loss 0.07936 | average ppl    1.083
# ------------------------------
#
# ------------------------------
# valid | epoch  15 | valid loss 7.27431 | valid ppl 1442.753
# ------------------------------
#
# ------------------------------
# | test loss  7.28 | test ppl  1448.84
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 16 batch 0 loss=7.167647838592529 perplexity=1296.790751477214 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  16 | average loss 0.07791 | average ppl    1.081
# ------------------------------
#
# ------------------------------
# valid | epoch  16 | valid loss 7.12600 | valid ppl 1243.887
# ------------------------------
#
# ------------------------------
# | test loss  7.13 | test ppl  1249.94
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 17 batch 0 loss=7.017159938812256 perplexity=1115.613703064691 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  17 | average loss 0.07627 | average ppl    1.079
# ------------------------------
#
# ------------------------------
# valid | epoch  17 | valid loss 6.96021 | valid ppl 1053.857
# ------------------------------
#
# ------------------------------
# | test loss  6.97 | test ppl  1059.68
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 18 batch 0 loss=6.847670555114746 perplexity=941.6847470307522 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  18 | average loss 0.07443 | average ppl    1.077
# ------------------------------
#
# ------------------------------
# valid | epoch  18 | valid loss 6.77907 | valid ppl  879.254
# ------------------------------
#
# ------------------------------
# | test loss  6.79 | test ppl   884.65
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 19 batch 0 loss=6.665591716766357 perplexity=784.9277825244915 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  19 | average loss 0.07245 | average ppl    1.075
# ------------------------------
#
# ------------------------------
# valid | epoch  19 | valid loss 6.58781 | valid ppl  726.187
# ------------------------------
#
# ------------------------------
# | test loss  6.59 | test ppl   731.00
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 20 batch 0 loss=6.470832347869873 perplexity=646.0212176288121 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  20 | average loss 0.07034 | average ppl    1.073
# ------------------------------
#
# ------------------------------
# valid | epoch  20 | valid loss 6.39627 | valid ppl  599.607
# ------------------------------
#
# ------------------------------
# | test loss  6.40 | test ppl   603.75
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 21 batch 0 loss=6.27716064453125 perplexity=532.2751977146999 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  21 | average loss 0.06823 | average ppl    1.071
# ------------------------------
#
# ------------------------------
# valid | epoch  21 | valid loss 6.21976 | valid ppl  502.582
# ------------------------------
#
# ------------------------------
# | test loss  6.23 | test ppl   506.06
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 22 batch 0 loss=6.094921112060547 perplexity=443.59904918182997 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  22 | average loss 0.06625 | average ppl    1.068
# ------------------------------
# ------------------------------
# valid | epoch  22 | valid loss 6.07700 | valid ppl  435.721
# ------------------------------
#
# ------------------------------
# | test loss  6.08 | test ppl   438.60
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 23 batch 0 loss=5.947961330413818 perplexity=382.97178973128456 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  23 | average loss 0.06465 | average ppl    1.067
# ------------------------------
#
# ------------------------------
# valid | epoch  23 | valid loss 5.98260 | valid ppl  396.469
# ------------------------------
#
# ------------------------------
# | test loss  5.99 | test ppl   398.91
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 24 batch 0 loss=5.849922180175781 perplexity=347.2073598116684 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  24 | average loss 0.06359 | average ppl    1.066
# ------------------------------
#
# ------------------------------
# valid | epoch  24 | valid loss 5.93504 | valid ppl  378.054
# ------------------------------
#
# ------------------------------
# | test loss  5.94 | test ppl   380.28
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 25 batch 0 loss=5.797067642211914 perplexity=329.33242211278395 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  25 | average loss 0.06301 | average ppl    1.065
# ------------------------------
#
# ------------------------------
# valid | epoch  25 | valid loss 5.91328 | valid ppl  369.919
# ------------------------------
#
# ------------------------------
# | test loss  5.92 | test ppl   372.13
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 26 batch 0 loss=5.771440505981445 perplexity=320.99980189536996 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  26 | average loss 0.06273 | average ppl    1.065
# ------------------------------
#
# ------------------------------
# valid | epoch  26 | valid loss 5.89209 | valid ppl  362.161
# ------------------------------
#
# ------------------------------
# | test loss  5.90 | test ppl   364.43
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 27 batch 0 loss=5.746633052825928 perplexity=313.13457581790954 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  27 | average loss 0.06246 | average ppl    1.064
# ------------------------------
#
# ------------------------------
# valid | epoch  27 | valid loss 5.85766 | valid ppl  349.903
# ------------------------------
#
# ------------------------------
# | test loss  5.86 | test ppl   352.23
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 28 batch 0 loss=5.708791732788086 perplexity=301.50654763228096 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  28 | average loss 0.06205 | average ppl    1.064
# ------------------------------
#
# ------------------------------
# valid | epoch  28 | valid loss 5.80695 | valid ppl  332.602
# ------------------------------
#
# ------------------------------
# | test loss  5.81 | test ppl   334.96
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 29 batch 0 loss=5.65231990814209 perplexity=284.95176152675987 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  29 | average loss 0.06144 | average ppl    1.063
# ------------------------------
#
# ------------------------------
# valid | epoch  29 | valid loss 5.74219 | valid ppl  311.747
# ------------------------------
#
# ------------------------------
# | test loss  5.75 | test ppl   314.07
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 30 batch 0 loss=5.580171585083008 perplexity=265.1170920219769 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  30 | average loss 0.06065 | average ppl    1.063
# ------------------------------
#
# ------------------------------
# valid | epoch  30 | valid loss 5.66782 | valid ppl  289.404
# ------------------------------
#
# ------------------------------
# | test loss  5.68 | test ppl   291.65
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 31 batch 0 loss=5.4988112449646 perplexity=244.4012263209304 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  31 | average loss 0.05977 | average ppl    1.062
# ------------------------------
#
# ------------------------------
# valid | epoch  31 | valid loss 5.58885 | valid ppl  267.427
# ------------------------------
#
# ------------------------------
# | test loss  5.60 | test ppl   269.59
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 32 batch 0 loss=5.4114532470703125 perplexity=223.95681589140622 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  32 | average loss 0.05882 | average ppl    1.061
# ------------------------------
#
# ------------------------------
# valid | epoch  32 | valid loss 5.50995 | valid ppl  247.139
# ------------------------------
#
# ------------------------------
# | test loss  5.52 | test ppl   249.21
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 33 batch 0 loss=5.324244976043701 perplexity=205.2533307647416 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  33 | average loss 0.05787 | average ppl    1.060
# ------------------------------
#
# ------------------------------
# valid | epoch  33 | valid loss 5.43521 | valid ppl  229.341
# ------------------------------
#
# ------------------------------
# | test loss  5.44 | test ppl   231.32
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 34 batch 0 loss=5.241163730621338 perplexity=188.88979138576988 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  34 | average loss 0.05697 | average ppl    1.059
# ------------------------------
#
# ------------------------------
# valid | epoch  34 | valid loss 5.36764 | valid ppl  214.356
# ------------------------------
#
# ------------------------------
# | test loss  5.38 | test ppl   216.26
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 35 batch 0 loss=5.16582727432251 perplexity=175.18232247958517 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  35 | average loss 0.05615 | average ppl    1.058
# ------------------------------
#
# ------------------------------
# valid | epoch  35 | valid loss 5.30884 | valid ppl  202.116
# ------------------------------
#
# ------------------------------
# | test loss  5.32 | test ppl   203.96
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 36 batch 0 loss=5.09962272644043 perplexity=163.96003784267623 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  36 | average loss 0.05543 | average ppl    1.057
# ------------------------------
#
# ------------------------------
# valid | epoch  36 | valid loss 5.25898 | valid ppl  192.285
# ------------------------------
#
# ------------------------------
# | test loss  5.27 | test ppl   194.09
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 37 batch 0 loss=5.042314052581787 perplexity=154.82788066322848 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  37 | average loss 0.05481 | average ppl    1.056
# ------------------------------
#
# ------------------------------
# valid | epoch  37 | valid loss 5.21694 | valid ppl  184.368
# ------------------------------
#
# ------------------------------
# | test loss  5.23 | test ppl   186.14
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 38 batch 0 loss=4.993739128112793 perplexity=147.48686605388778 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  38 | average loss 0.05428 | average ppl    1.056
# ------------------------------
#
# ------------------------------
# valid | epoch  38 | valid loss 5.18059 | valid ppl  177.789
# ------------------------------
#
# ------------------------------
# | test loss  5.19 | test ppl   179.54
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 39 batch 0 loss=4.951020240783691 perplexity=141.3190698761919 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  39 | average loss 0.05382 | average ppl    1.055
# ------------------------------
#
# ------------------------------
# valid | epoch  39 | valid loss 5.14754 | valid ppl  172.007
# ------------------------------
#
# ------------------------------
# | test loss  5.16 | test ppl   173.75
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 40 batch 0 loss=4.9130682945251465 perplexity=136.05623521858274 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  40 | average loss 0.05340 | average ppl    1.055
# ------------------------------
#
# ------------------------------
# valid | epoch  40 | valid loss 5.11561 | valid ppl  166.603
# ------------------------------
#
# ------------------------------
# | test loss  5.13 | test ppl   168.34
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 41 batch 0 loss=4.8761982917785645 perplexity=131.13119253248848 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  41 | average loss 0.05300 | average ppl    1.054
# ------------------------------
#
# ------------------------------
# valid | epoch  41 | valid loss 5.08329 | valid ppl  161.305
# ------------------------------
#
# ------------------------------
# | test loss  5.09 | test ppl   163.04
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 42 batch 0 loss=4.839727878570557 perplexity=126.43494139144883 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  42 | average loss 0.05261 | average ppl    1.054
# ------------------------------
#
# ------------------------------
# valid | epoch  42 | valid loss 5.04977 | valid ppl  155.987
# ------------------------------
#
# ------------------------------
# | test loss  5.06 | test ppl   157.72
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 43 batch 0 loss=4.802361965179443 perplexity=121.79776010686015 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  43 | average loss 0.05220 | average ppl    1.054
# ------------------------------
#
# ------------------------------
# valid | epoch  43 | valid loss 5.01491 | valid ppl  150.643
# ------------------------------
#
# ------------------------------
# | test loss  5.03 | test ppl   152.36
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 44 batch 0 loss=4.763396739959717 perplexity=117.1431557118833 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  44 | average loss 0.05178 | average ppl    1.053
# ------------------------------
#
# ------------------------------
# valid | epoch  44 | valid loss 4.97912 | valid ppl  145.346
# ------------------------------
#
# ------------------------------
# | test loss  4.99 | test ppl   147.06
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 45 batch 0 loss=4.725065231323242 perplexity=112.73785217349429 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  45 | average loss 0.05136 | average ppl    1.053
# ------------------------------
#
# ------------------------------
# valid | epoch  45 | valid loss 4.94312 | valid ppl  140.208
# ------------------------------
#
# ------------------------------
# | test loss  4.96 | test ppl   141.92
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 46 batch 0 loss=4.685493469238281 perplexity=108.36373328534673 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  46 | average loss 0.05093 | average ppl    1.052
# ------------------------------
#
# ------------------------------
# valid | epoch  46 | valid loss 4.90780 | valid ppl  135.342
# ------------------------------
#
# ------------------------------
# | test loss  4.92 | test ppl   137.04
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 47 batch 0 loss=4.647508144378662 perplexity=104.32469932545989 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  47 | average loss 0.05052 | average ppl    1.052
# ------------------------------
#
# ------------------------------
# valid | epoch  47 | valid loss 4.87398 | valid ppl  130.841
# ------------------------------
# ------------------------------
# | test loss  4.89 | test ppl   132.54
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 48 batch 0 loss=4.611364364624023 perplexity=100.62134022313839 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  48 | average loss 0.05012 | average ppl    1.051
# ------------------------------
#
# ------------------------------
# valid | epoch  48 | valid loss 4.84238 | valid ppl  126.771
# ------------------------------
#
# ------------------------------
# | test loss  4.86 | test ppl   128.47
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 49 batch 0 loss=4.577111721038818 perplexity=97.23315178265607 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  49 | average loss 0.04975 | average ppl    1.051
# ------------------------------
#
# ------------------------------
# valid | epoch  49 | valid loss 4.81354 | valid ppl  123.167
# ------------------------------
#
# ------------------------------
# | test loss  4.83 | test ppl   124.87
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 50 batch 0 loss=4.5456366539001465 perplexity=94.22039389961722 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  50 | average loss 0.04941 | average ppl    1.051
# ------------------------------
#
# ------------------------------
# valid | epoch  50 | valid loss 4.78770 | valid ppl  120.025
# ------------------------------
#
# ------------------------------
# | test loss  4.80 | test ppl   121.73
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 51 batch 0 loss=4.517513751983643 perplexity=91.60755550739191 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  51 | average loss 0.04910 | average ppl    1.050
# ------------------------------
#
# ------------------------------
# valid | epoch  51 | valid loss 4.76489 | valid ppl  117.318
# ------------------------------
#
# ------------------------------
# | test loss  4.78 | test ppl   119.03
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 52 batch 0 loss=4.491783618927002 perplexity=89.28054642152055 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  52 | average loss 0.04882 | average ppl    1.050
# ------------------------------
#
# ------------------------------
# valid | epoch  52 | valid loss 4.74492 | valid ppl  114.999
# ------------------------------
#
# ------------------------------
# | test loss  4.76 | test ppl   116.72
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 53 batch 0 loss=4.46921443939209 perplexity=87.28812596010462 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  53 | average loss 0.04858 | average ppl    1.050
# ------------------------------
#
# ------------------------------
# valid | epoch  53 | valid loss 4.72749 | valid ppl  113.012
# ------------------------------
#
# ------------------------------
# | test loss  4.74 | test ppl   114.74
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 54 batch 0 loss=4.448858737945557 perplexity=85.52927696261682 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  54 | average loss 0.04836 | average ppl    1.050
# ------------------------------
#
# ------------------------------
# valid | epoch  54 | valid loss 4.71218 | valid ppl  111.294
# ------------------------------
#
# ------------------------------
# | test loss  4.73 | test ppl   113.04
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 55 batch 0 loss=4.430412292480469 perplexity=83.9660283368612 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  55 | average loss 0.04816 | average ppl    1.049
# ------------------------------
#
# ------------------------------
# valid | epoch  55 | valid loss 4.69856 | valid ppl  109.789
# ------------------------------
#
# ------------------------------
# | test loss  4.71 | test ppl   111.55
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 56 batch 0 loss=4.413184642791748 perplexity=82.53187998772813 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  56 | average loss 0.04797 | average ppl    1.049
# ------------------------------
#
# ------------------------------
# valid | epoch  56 | valid loss 4.68628 | valid ppl  108.449
# ------------------------------
#
# ------------------------------
# | test loss  4.70 | test ppl   110.22
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 57 batch 0 loss=4.397157669067383 perplexity=81.21968704444869 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  57 | average loss 0.04780 | average ppl    1.049
# ------------------------------
#
# ------------------------------
# valid | epoch  57 | valid loss 4.67507 | valid ppl  107.240
# ------------------------------
#
# ------------------------------
# | test loss  4.69 | test ppl   109.02
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 58 batch 0 loss=4.381875991821289 perplexity=79.98794947947778 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  58 | average loss 0.04763 | average ppl    1.049
# ------------------------------
#
# ------------------------------
# valid | epoch  58 | valid loss 4.66471 | valid ppl  106.135
# ------------------------------
#
# ------------------------------
# | test loss  4.68 | test ppl   107.92
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 59 batch 0 loss=4.367063045501709 perplexity=78.81182471978396 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  59 | average loss 0.04747 | average ppl    1.049
# ------------------------------
#
# ------------------------------
# valid | epoch  59 | valid loss 4.65510 | valid ppl  105.120
# ------------------------------
#
# ------------------------------
# | test loss  4.67 | test ppl   106.91
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 60 batch 0 loss=4.352972984313965 perplexity=77.70914792173406 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  60 | average loss 0.04731 | average ppl    1.048
# ------------------------------
# ------------------------------
# valid | epoch  60 | valid loss 4.64624 | valid ppl  104.192
# ------------------------------
#
# ------------------------------
# | test loss  4.66 | test ppl   105.99
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 61 batch 0 loss=4.338924884796143 perplexity=76.62511421269477 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  61 | average loss 0.04716 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  61 | valid loss 4.63809 | valid ppl  103.347
# ------------------------------
#
# ------------------------------
# | test loss  4.66 | test ppl   105.15
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 62 batch 0 loss=4.325489521026611 perplexity=75.60251282254914 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  62 | average loss 0.04702 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  62 | valid loss 4.63072 | valid ppl  102.588
# ------------------------------
#
# ------------------------------
# | test loss  4.65 | test ppl   104.40
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 63 batch 0 loss=4.312623023986816 perplexity=74.6360044372457 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  63 | average loss 0.04688 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  63 | valid loss 4.62414 | valid ppl  101.916
# ------------------------------
#
# ------------------------------
# | test loss  4.64 | test ppl   103.73
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 64 batch 0 loss=4.300230026245117 perplexity=73.71674853636038 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  64 | average loss 0.04674 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  64 | valid loss 4.61835 | valid ppl  101.327
# ------------------------------
#
# ------------------------------
# | test loss  4.64 | test ppl   103.14
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 65 batch 0 loss=4.288358688354492 perplexity=72.84680601373186 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  65 | average loss 0.04661 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  65 | valid loss 4.61329 | valid ppl  100.815
# ------------------------------
#
# ------------------------------
# | test loss  4.63 | test ppl   102.63
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 66 batch 0 loss=4.276801586151123 perplexity=72.00975429440312 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  66 | average loss 0.04649 | average ppl    1.048
# ------------------------------
#
# ------------------------------
# valid | epoch  66 | valid loss 4.60893 | valid ppl  100.377
# ------------------------------
#
# ------------------------------
# | test loss  4.63 | test ppl   102.19
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 67 batch 0 loss=4.265859603881836 perplexity=71.22611991493983 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  67 | average loss 0.04637 | average ppl    1.047
# ------------------------------
#
# ------------------------------
# valid | epoch  67 | valid loss 4.60518 | valid ppl  100.001
# ------------------------------
#
# ------------------------------
# | test loss  4.62 | test ppl   101.81
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 68 batch 0 loss=4.255645751953125 perplexity=70.50232950899635 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  68 | average loss 0.04626 | average ppl    1.047
# ------------------------------
#
# ------------------------------
# valid | epoch  68 | valid loss 4.60191 | valid ppl   99.674
# ------------------------------
#
# ------------------------------
# | test loss  4.62 | test ppl   101.48
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 69 batch 0 loss=4.245639801025391 perplexity=69.80040423091356 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  69 | average loss 0.04615 | average ppl    1.047
# ------------------------------
#
# ------------------------------
# valid | epoch  69 | valid loss 4.59905 | valid ppl   99.390
# ------------------------------
#
# ------------------------------
# | test loss  4.62 | test ppl   101.20
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# ...
# ------------------------------
#
# ------------------------------
# valid | epoch  94 | valid loss 4.57222 | valid ppl   96.758
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.45
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 95 batch 0 loss=3.993844985961914 perplexity=54.26312973820982 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  95 | average loss 0.04341 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch  95 | valid loss 4.57210 | valid ppl   96.747
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.44
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 96 batch 0 loss=3.983799695968628 perplexity=53.720769507637435 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  96 | average loss 0.04330 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch  96 | valid loss 4.57201 | valid ppl   96.738
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.43
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 97 batch 0 loss=3.973663330078125 perplexity=53.17898662557503 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  97 | average loss 0.04319 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch  97 | valid loss 4.57187 | valid ppl   96.725
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.42
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 98 batch 0 loss=3.9632434844970703 perplexity=52.62774670170235 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  98 | average loss 0.04308 | average ppl    1.044
# ------------------------------
# ------------------------------
# valid | epoch  98 | valid loss 4.57173 | valid ppl   96.711
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.40
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 99 batch 0 loss=3.952814817428589 perplexity=52.08176135081642 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch  99 | average loss 0.04297 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch  99 | valid loss 4.57153 | valid ppl   96.692
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.39
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 100 batch 0 loss=3.9426279067993164 perplexity=51.55390229383152 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 100 | average loss 0.04285 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch 100 | valid loss 4.57130 | valid ppl   96.669
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.36
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 101 batch 0 loss=3.931800127029419 perplexity=50.998699226148396 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 101 | average loss 0.04274 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch 101 | valid loss 4.57102 | valid ppl   96.643
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.34
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 102 batch 0 loss=3.921199083328247 perplexity=50.46091535852215 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 102 | average loss 0.04262 | average ppl    1.044
# ------------------------------
#
# ------------------------------
# valid | epoch 102 | valid loss 4.57072 | valid ppl   96.613
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.31
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 103 batch 0 loss=3.9106533527374268 perplexity=49.93156424277205 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 103 | average loss 0.04251 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 103 | valid loss 4.57040 | valid ppl   96.583
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.28
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 104 batch 0 loss=3.899651050567627 perplexity=49.3852131563692 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 104 | average loss 0.04239 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 104 | valid loss 4.57004 | valid ppl   96.548
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.25
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 105 batch 0 loss=3.8885061740875244 perplexity=48.837876719586106 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 105 | average loss 0.04227 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 105 | valid loss 4.56969 | valid ppl   96.514
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.21
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 106 batch 0 loss=3.8771612644195557 perplexity=48.2869464558991 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 106 | average loss 0.04214 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 106 | valid loss 4.56935 | valid ppl   96.481
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.18
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 107 batch 0 loss=3.8669071197509766 perplexity=47.79433509182884 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 107 | average loss 0.04203 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 107 | valid loss 4.56899 | valid ppl   96.447
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.15
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 108 batch 0 loss=3.8550024032592773 perplexity=47.228730444022936 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 108 | average loss 0.04190 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 108 | valid loss 4.56866 | valid ppl   96.415
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.12
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 109 batch 0 loss=3.8436858654022217 perplexity=46.69727750332874 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 109 | average loss 0.04178 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 109 | valid loss 4.56837 | valid ppl   96.386
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.10
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 110 batch 0 loss=3.833031415939331 perplexity=46.20238480629443 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 110 | average loss 0.04166 | average ppl    1.043
# ------------------------------
#
# ------------------------------
# valid | epoch 110 | valid loss 4.56808 | valid ppl   96.359
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.07
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 111 batch 0 loss=3.8204472064971924 perplexity=45.62460738006507 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 111 | average loss 0.04153 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 111 | valid loss 4.56783 | valid ppl   96.334
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.05
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 112 batch 0 loss=3.8089253902435303 perplexity=45.10194582441865 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 112 | average loss 0.04140 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 112 | valid loss 4.56761 | valid ppl   96.314
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.04
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 113 batch 0 loss=3.797438144683838 perplexity=44.58681309021402 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 113 | average loss 0.04128 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 113 | valid loss 4.56740 | valid ppl   96.294
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.02
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 114 batch 0 loss=3.785855293273926 perplexity=44.07335008281642 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 114 | average loss 0.04115 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 114 | valid loss 4.56724 | valid ppl   96.278
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.01
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 115 batch 0 loss=3.773245096206665 perplexity=43.5210659770935 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 115 | average loss 0.04101 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 115 | valid loss 4.56712 | valid ppl   96.267
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.01
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 116 batch 0 loss=3.762058734893799 perplexity=43.036936480526634 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 116 | average loss 0.04089 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 116 | valid loss 4.56705 | valid ppl   96.260
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.00
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 117 batch 0 loss=3.748875856399536 perplexity=42.4733090547039 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 117 | average loss 0.04075 | average ppl    1.042
# ------------------------------
#
# ------------------------------
# valid | epoch 117 | valid loss 4.56698 | valid ppl   96.253
# ------------------------------
#
# ------------------------------
# | test loss  4.59 | test ppl    98.00
# ------------------------------
#
# [W LegacyDefinitions.cpp:72] Warning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (function masked_scatter__cuda)
# epoch 118 batch 0 loss=3.7367918491363525 perplexity=41.963149871144445 en_lr=0.00010 de_lr=0.00010
#
# ------------------------------
# train | epoch 118 | average loss 0.04062 | average ppl    1.041
# ------------------------------
#
# ------------------------------
# valid | epoch 118 | valid loss 4.56699 | valid ppl   96.254
# ------------------------------
# validation loss is larger than best validation loss. Break!
